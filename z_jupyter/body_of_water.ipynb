# %%
import geopandas as gpd

# %%
water_shp = gpd.read_file("../temp/body_of_water/ne_10m_geography_marine_polys.shp", layer='ne_10m_geography_marine_polys')

# %%
filter_bay = (water_shp["featurecla"] == "bay")

# %%
filter_channel = (water_shp["featurecla"] == "channel")

# %%
filter_fjord = (water_shp["featurecla"] == "fjord")

# %%
filter_gulf = (water_shp["featurecla"] == "gulf")

# %%
filter_lagoon = (water_shp["featurecla"] == "lagoon")

# %%
filter_ocean = (water_shp["featurecla"] == "ocean")

# %%
filter_reef = (water_shp["featurecla"] == "reef")

# %%
filter_sea = (water_shp["featurecla"] == "sea")

# %%
filter_sound = (water_shp["featurecla"] == "sound")

# %%
filter_strait = (water_shp["featurecla"] == "strait")

# %%
bay_body_of_water = water_shp.loc[filter_bay, ["name", "wikidataid", "featurecla", "geometry"]]

# %%
bay_body_of_water
# Out:
#                         name wikidataid featurecla  \
# 11             Bay of Bengal     Q38684        bay
# 19                Hudson Bay      Q3040        bay
# 21                Baffin Bay     Q37040        bay
# 33             Bay of Biscay     Q41573        bay
# 48         Bahía de Campeche     Q61304        bay
# 65                 James Bay    Q223810        bay
# 76             Bay of Plenty    Q140290        bay
# 85              Bay of Fundy    Q181857        bay
# 94                Cook Inlet   Q1129590        bay
# 95               Bristol Bay    Q917872        bay
# 96              Melville Bay   Q2336534        bay
# 98            Chesapeake Bay    Q216868        bay
# 110               Ungava Bay   Q1165951        bay
# 117             Franklin Bay   Q5491299        bay
# 120              Boca Grande       None        bay
# 121           Baía de Marajó       None        bay
# 125           Sulzberger Bay    Q281737        bay
# 129       Baía de São Marcos   Q2060432        bay
# 131            Frobisher Bay   Q1004067        bay
# 132                Disko Bay   Q1135227        bay
# 133           Hamilton Inlet       None        bay
# 145                  Uda Bay   Q1141758        bay
# 146              Uchiura Bay   Q1036267        bay
# 149                Shark Bay    Q217487        bay
# 151            Mackenzie Bay   Q4275770        bay
# 155               Kane Basin   Q1510928        bay
# 156               Foxe Basin    Q845217        bay
# 163           East Korea Bay     Q52060        bay
# 167            Geographe Bay   Q1503116        bay
# 176           Bight of Benin     Q47530        bay
# 177          Bight of Biafra    Q999031        bay
# 181             Bahía Blanca       None        bay
# 183             Bahía Grande       None        bay
# 184           Marguerite Bay    Q141727        bay
# 185                Prydz Bay    Q156116        bay
# 186            Vincennes Bay    Q281808        bay
# 187             Porpoise Bay   Q7230362        bay
# 189          Lützow-Holm Bay    Q156123        bay
# 190            Antongila Bay    Q803725        bay
# 191             Hangzhou Bay    Q700024        bay
# 198           Baia de Maputo   Q1134899        bay
# 199           St. Helena Bay       None        bay
# 206                Chaun Bay    Q915250        bay
# 208            Garabogaz Bay    Q239379        bay
# 217        Massachusetts Bay    Q959127        bay
# 218             Delaware Bay    Q738808        bay
# 231              Darnley Bay   Q1166530        bay
# 235  Richard Collinson Inlet   Q7324843        bay
# 238             Wynniatt Bay   Q8040226        bay
# 239               Hadley Bay       None        bay
# 240           Bathurst Inlet    Q810805        bay
# 243            Sherman Basin       None        bay
# 244                Wager Bay   Q2539134        bay
# 255               Bay Inútil    Q750763        bay
# 262            Guba Gusinaya       None        bay
# 279              Tayabas Bay    Q999060        bay
# 284              Cordova Bay   Q5170043        bay
# 295      Mecklenburger Bucht    Q317006        bay
# 297        San Francisco Bay    Q232264        bay
# 298             Monterey Bay    Q584588        bay
#
#                                               geometry
# 11   POLYGON ((95.22419 5.52191, 95.19985 5.52403, ...
# 19   POLYGON ((-85.69892 65.88342, -85.81375 65.832...
# 21   POLYGON ((-72.69837 78.37969, -72.71478 78.362...
# 33   POLYGON ((-7.99821 43.69493, -7.99927 43.70922...
# 48   POLYGON ((-97.19507 20.80000, -90.35295 21.009...
# 65   POLYGON ((-82.22283 54.83337, -82.18844 54.839...
# 76   POLYGON ((175.77235 -36.73523, 178.27215 -37.5...
# 85   POLYGON ((-66.19174 44.14684, -67.18657 44.679...
# 94   POLYGON ((-151.95855 59.27783, -151.96648 59.2...
# 95   POLYGON ((-161.43802 55.96842, -162.13178 58.6...
# 96   POLYGON ((-57.19749 74.13473, -66.73096 75.974...
# 98   POLYGON ((-75.93898 37.15760, -76.00143 36.912...
# 110  POLYGON ((-67.83531 60.41236, -64.88469 60.288...
# 117  POLYGON ((-125.89231 69.41561, -125.35521 69.6...
# 120  POLYGON ((-60.79370 9.35783, -60.33068 8.62810...
# 121  POLYGON ((-48.38898 -0.31218, -48.03497 -0.705...
# 125  POLYGON ((-158.00322 -77.09106, -148.46393 -76...
# 129  POLYGON ((-44.54616 -1.95471, -44.54510 -1.954...
# 131  POLYGON ((-65.49959 62.83542, -65.50222 62.829...
# 132  POLYGON ((-54.27226 70.31150, -54.25692 70.528...
# 133  POLYGON ((-57.57266 54.43650, -57.39698 54.160...
# 145  POLYGON ((138.12375 56.48172, 138.20948 55.033...
# 146  POLYGON ((143.24503 42.00741, 143.24555 42.006...
# 149  POLYGON ((113.39740 -25.64706, 113.41275 -24.2...
# 151  POLYGON ((-139.17282 69.51191, -139.03947 69.5...
# 155  POLYGON ((-72.69837 78.37969, -74.53880 78.647...
# 156  POLYGON ((-85.69892 65.88342, -85.71639 65.916...
# 163  POLYGON ((128.31303 40.04104, 128.31303 38.694...
# 167  POLYGON ((115.01663 -33.52953, 115.01663 -30.3...
# 176  POLYGON ((5.58336 4.65778, 5.57173 4.65302, 0....
# 177  POLYGON ((8.44458 3.38778, 6.62319 4.32069, 6....
# 181  POLYGON ((-61.40805 -38.98315, -61.40805 -38.9...
# 183  POLYGON ((-67.91099 -49.98238, -67.90993 -49.9...
# 184  POLYGON ((-67.70832 -67.15704, -67.50249 -67.1...
# 185  POLYGON ((69.57971 -67.78516, 79.13861 -68.152...
# 186  POLYGON ((104.36028 -66.05741, 110.99708 -66.0...
# 187  POLYGON ((126.42389 -66.46225, 130.57837 -66.2...
# 189  POLYGON ((34.20073 -68.72862, 40.65233 -68.728...
# 190  POLYGON ((50.19480 -15.95908, 49.82805 -16.249...
# 191  POLYGON ((122.01486 30.02284, 122.00271 29.888...
# 198  MULTIPOLYGON (((32.99122 -25.47241, 32.96086 -...
# 199  MULTIPOLYGON (((18.00615 -32.74660, 18.03676 -...
# 206  POLYGON ((169.43083 69.83734, 170.16742 69.635...
# 208  POLYGON ((52.94326 41.03799, 52.92001 41.08191...
# 217  POLYGON ((-70.61450 42.62337, -70.23987 42.085...
# 218  POLYGON ((-74.93780 38.94514, -75.08862 38.777...
# 231  POLYGON ((-124.13231 69.66908, -123.08721 69.7...
# 235  POLYGON ((-114.11784 73.21607, -113.17115 72.9...
# 238  POLYGON ((-111.28943 72.71921, -110.68143 72.9...
# 239  POLYGON ((-108.73938 72.53663, -108.23243 73.0...
# 240  POLYGON ((-108.04883 67.66512, -107.95410 67.7...
# 243  POLYGON ((-98.41481 67.98843, -98.38781 68.035...
# 244  POLYGON ((-87.67803 65.33521, -87.68012 65.271...
# 255  POLYGON ((-70.53143 -53.62784, -70.42347 -53.3...
# 262  POLYGON ((146.82479 72.27896, 147.14901 72.298...
# 279  POLYGON ((120.93379 13.49698, 120.94118 13.529...
# 284  POLYGON ((-133.31234 55.54630, -133.30630 55.5...
# 295  POLYGON ((12.05640 54.84613, 12.46370 54.39910...
# 297  POLYGON ((-122.51411 37.77188, -122.51444 37.7...
# 298  POLYGON ((-121.91867 36.57248, -121.91934 36.5...
