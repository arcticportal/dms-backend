# %%
import geopandas as gpd

# %%
airports_shp = gpd.read_file("../temp/airports/ne_10m_airports.shp", layer='ne_10m_airports')

# %%
filter_airports = airports_shp[["name", "type", "gps_code", "iata_code", "wikipedia", "wikidataid", "geometry" ]]

# %%
filter_airports
# Out:
#                             name              type gps_code iata_code  \
# 0                       Sahnewal             small     VILD       LUH
# 1                        Solapur               mid     VASL       SSE
# 2                    Birsa Munda               mid     VERC       IXR
# 3                          Ahwaz               mid     OIAW       AWZ
# 4                        Gwalior  mid and military     VIGR       GWL
# ..                           ...               ...      ...       ...
# 888                      Arlanda             major     ESSA       ARN
# 889         Soekarno-Hatta Int'l             major     WIII       CGK
# 890  Eleftherios Venizelos Int'l             major     LGAV       ATH
# 891                  Tokyo Int'l             major     RJTT       HND
# 892         Suvarnabhumi Airport             major     VTBS       BKK
#
#                                              wikipedia wikidataid  \
# 0        http://en.wikipedia.org/wiki/Sahnewal_Airport   Q7399709
# 1         http://en.wikipedia.org/wiki/Solapur_Airport   Q7555807
# 2     http://en.wikipedia.org/wiki/Birsa_Munda_Airport    Q598231
# 3           http://en.wikipedia.org/wiki/Ahwaz_Airport    Q622296
# 4         http://en.wikipedia.org/wiki/Gwalior_Airport   Q2247561
# ..                                                 ...        ...
# 888  http://en.wikipedia.org/wiki/Stockholm-Arlanda...    Q223499
# 889  http://en.wikipedia.org/wiki/Soekarno-Hatta_In...    Q749497
# 890  http://en.wikipedia.org/wiki/Athens_Internatio...    Q211734
# 891       https://en.wikipedia.org/wiki/Haneda_Airport    Q204853
# 892  https://en.wikipedia.org/wiki/Suvarnabhumi_Air...    Q194316
#
#                        geometry
# 0     POINT (75.95707 30.85036)
# 1     POINT (75.93306 17.62542)
# 2     POINT (85.32360 23.31772)
# 3     POINT (48.74711 31.34316)
# 4     POINT (78.21722 26.28549)
# ..                          ...
# 888   POINT (17.93073 59.65112)
# 889  POINT (106.65430 -6.12660)
# 890   POINT (23.94712 37.93623)
# 891  POINT (139.78405 35.54906)
# 892  POINT (100.75091 13.69261)
#
# [893 rows x 7 columns]
